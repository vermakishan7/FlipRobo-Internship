# %%
#Importing required libraries
from selenium import webdriver
from selenium.common.exceptions import StaleElementReferenceException
import shutil
import os
import pandas as pd
import requests
import time

# %%
#function to make directory
def make_directory(dirname):
    current_path=os.getcwd()
    path=os.path.join(current_path, dirname)
    if not os.path.exists(path):
        os.makedirs(path)
        
#function to scrape images
def  scrap_images_url(driver):
    
   
    s=driver.find_elements_by_xpath("//div[@class='a-section aok-relative s-image-tall-aspect']//img")
    print(len(s))
    product_data={}

    product_data['image_urls']=[]
        
    for image in s:
        source=image.get_attribute('src')
        product_data["image_urls"].append(source)
    print("R S Data")

    return product_data
    
#function to sace images in the directory
def save_images(data, dirname, page):
    for index,link in enumerate(data['image_urls']):
        response=requests.get(link)
        with open("{0}/img _{0}{1}{2}.jpeg".format(dirname,page,index),"wb") as file:
            file.write(response.content)

# %%
#sCRAPPING IMAGE OF SAREES
driver= webdriver.Chrome(r"chromedriver")
currentpageurl=driver.get('https://www.amazon.in/s?k=sarees&ref=nb_sb_noss')
DIRNAME="Sarees"
make_directory(DIRNAME)
start_page=1
total_pages=5
for page in range(start_page,total_pages):
    time.sleep(2)
    try:
        prod_details=scrap_images_url(driver=driver)
        print("Scrapping page {0} of {1} pages".format(page,total_pages))
        
        # Downloading the images
        save_images(data=prod_details,dirname=DIRNAME,page=page)
        print("Scrapping of page{0}Done!!".format(page))
                 
        # Moving to the next page
        print("Moving to the next page")
        try:
            
            driver.find_element_by_xpath("//a[@class='s-pagination-item s-pagination-next s-pagination-button s-pagination-separator']").click()
        
        except:
            driver.find_element_by_xpath("//li[@class='a-last']//a").click()

    except StaleElementReferenceException as Exception:
        print("We are facing an exception")   
        print("The page value at the time out exception is {}".format(exception_page))
              
        # Moving to the next page
        print("Moving to the next page")
        try:    
            driver.find_element_by_xpath("//a[@class='s-pagination-item s-pagination-next s-pagination-button s-pagination-separator']").click()
        
        except:
            driver.find_element_by_xpath("//li[@class='a-last']//a").click()

        print("the new page is {}".format(new_page))
# Out:
# 68
# R S Data
# Scrapping page 1 of 5 pages
# Scrapping of page1Done!!
# Moving to the next page
# 60
# R S Data
# Scrapping page 2 of 5 pages
# Scrapping of page2Done!!
# Moving to the next page
# 60
# R S Data
# Scrapping page 3 of 5 pages
# Scrapping of page3Done!!
# Moving to the next page
# 60
# R S Data
# Scrapping page 4 of 5 pages
# Scrapping of page4Done!!
# Moving to the next page

# %%
#scraping Jeans(men) image
driver= webdriver.Chrome(r"chromedriver")
currentpageurl=driver.get('https://www.amazon.in/s?k=jeans+mens&crid=3CNCRJ3TX0TOB&sprefix=jeans+m%2Caps%2C423&ref=nb_sb_ss_ts-doa-p_4_7')

DIRNAME="Jeans"
make_directory(DIRNAME)
start_page=1
total_pages=7
for page in range(start_page,total_pages):
    time.sleep(2)
    try:
        prod_details=scrap_images_url(driver=driver)
        print("Scrapping page {0} of {1} pages".format(page,total_pages))
        
        # Downloading the images
        save_images(data=prod_details,dirname=DIRNAME,page=page)
        print("Scrapping of page{0}Done!!".format(page))
        
        # Moving to the next page
        print("Moving to the next page")
        try:
            
            driver.find_element_by_xpath("//a[@class='s-pagination-item s-pagination-next s-pagination-button s-pagination-separator']").click()
        
        except:
            driver.find_element_by_xpath("//li[@class='a-last']//a").click()
     

    except StaleElementReferenceException as Exception:
        print("We are facing an exception")   
        print("The page value at the time out exception is {}".format(exception_page))
              
        # Moving to the next page
        print("Moving to the next page")
        try:
            
            driver.find_element_by_xpath("//a[@class='s-pagination-item s-pagination-next s-pagination-button s-pagination-separator']").click()
        
        except:
            driver.find_element_by_xpath("//li[@class='a-last']//a").click()

        print("the new page is {}".format(new_page))
# Out:
# 73
# R S Data
# Scrapping page 1 of 7 pages
# Scrapping of page1Done!!
# Moving to the next page
# 10
# R S Data
# Scrapping page 2 of 7 pages
# Scrapping of page2Done!!
# Moving to the next page
# 10
# R S Data
# Scrapping page 3 of 7 pages
# Scrapping of page3Done!!
# Moving to the next page
# 10
# R S Data
# Scrapping page 4 of 7 pages
# Scrapping of page4Done!!
# Moving to the next page
# 10
# R S Data
# Scrapping page 5 of 7 pages
# Scrapping of page5Done!!
# Moving to the next page
# 10
# R S Data
# Scrapping page 6 of 7 pages
# Scrapping of page6Done!!
# Moving to the next page

# %%
#scraping Trousers(men) image
driver= webdriver.Chrome(r"chromedriver")
currentpageurl=driver.get('https://www.amazon.in/s?k=trouser+for+men&crid=3DBEFGLCYKE7V&sprefix=trou%2Caps%2C430&ref=nb_sb_ss_ts-doa-p_3_4')
DIRNAME="Trousers"
make_directory(DIRNAME)
start_page=1
total_pages=7
for page in range(start_page,total_pages):
    time.sleep(2)
    try:
        prod_details=scrap_images_url(driver=driver)
        print("Scrapping page {0} of {1} pages".format(page,total_pages))
        
        
        # Downloading the images
        save_images(data=prod_details,dirname=DIRNAME,page=page)
        print("Scrapping of page{0}Done!!".format(page))

        # Moving to the next page
        print("Moving to the next page")
        try:
            
            driver.find_element_by_xpath("//a[@class='s-pagination-item s-pagination-next s-pagination-button s-pagination-separator']").click()
        
        except:
            driver.find_element_by_xpath("//li[@class='a-last']//a").click()
       

    except StaleElementReferenceException as Exception:
        print("We are facing an exception")   
        print("The page value at the time out exception is {}".format(exception_page))
              
        # Moving to the next page
        print("Moving to the next page")
        try:
            
            driver.find_element_by_xpath("//a[@class='s-pagination-item s-pagination-next s-pagination-button s-pagination-separator']").click()
        
        except:
            driver.find_element_by_xpath("//li[@class='a-last']//a").click()

        print("the new page is {}".format(new_page))
# Out:
# 74
# R S Data
# Scrapping page 1 of 7 pages
# Scrapping of page1Done!!
# Moving to the next page
# 48
# R S Data
# Scrapping page 2 of 7 pages
# Scrapping of page2Done!!
# Moving to the next page
# 60
# R S Data
# Scrapping page 3 of 7 pages
# Scrapping of page3Done!!
# Moving to the next page
# 46
# R S Data
# Scrapping page 4 of 7 pages
# Scrapping of page4Done!!
# Moving to the next page
# 10
# R S Data
# Scrapping page 5 of 7 pages
# Scrapping of page5Done!!
# Moving to the next page
# 60
# R S Data
# Scrapping page 6 of 7 pages
# Scrapping of page6Done!!
# Moving to the next page
